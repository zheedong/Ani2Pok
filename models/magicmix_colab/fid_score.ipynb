# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = '/Colab Notebooks/Ani2Pok/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/

# %%
# !pip install pytorch-fid

# %%
# Image size : [3, 538, 836]
original_pokemon_path = "data/archive/pokemon/pokemon"
stat_npz = "data/archive/original_pokemon.npz"

# !python -m pytorch_fid --save-stats $original_pokemon_path $stat_npz
# !pwd
fid_score = np.load(stat_npz)
for data in fid_score:
    print(data)
print(f"mu : {fid_score['mu']}")
print()
print(f"sigma : {fid_score['sigma']}")

# %%
import os
import torch
import subprocess
import numpy as np
 
# Image size : [3, 538, 836]

test_data_path = "data/generated_images"
# test_data_path = "data/archive/pokemon_jpg/pokemon_jpg"

# !python -m pytorch_fid $stat_npz $test_data_path --device cuda:0
